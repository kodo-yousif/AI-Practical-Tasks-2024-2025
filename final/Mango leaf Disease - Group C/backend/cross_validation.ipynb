# %% [markdown]
# # Imports and Constants

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from skimage.feature import local_binary_pattern, graycomatrix, graycoprops

DATA_DIR = "/Users/oneaboveall/Downloads/MangoLeafBD"
CATEGORIES = []
used_features = {
    'hsv': True,  # Enable HSV features
    'lbp': True,  # Enable LBP features
    'glcm': True  # Enable GLCM features
}

# %% [markdown]
# # Extract Features

# %%
def extract_features(img_path, img_size=(256, 256)):
    img = cv2.imread(img_path, cv2.IMREAD_COLOR)
    img = cv2.resize(img, img_size)
    features = []

    if used_features['hsv']:
        hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
        hist_h = cv2.calcHist([hsv], [0], None, [32], [0, 180]).flatten()
        hist_s = cv2.calcHist([hsv], [1], None, [32], [0, 256]).flatten()
        hist_v = cv2.calcHist([hsv], [2], None, [32], [0, 256]).flatten()
        hist_h /= (hist_h.sum() + 1e-7)
        hist_s /= (hist_s.sum() + 1e-7)
        hist_v /= (hist_v.sum() + 1e-7)
        features.extend([hist_h, hist_s, hist_v])

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    if used_features['lbp']:
        lbp = local_binary_pattern(gray, P=8, R=1, method='uniform')
        lbp_hist, _ = np.histogram(lbp, bins=np.arange(0, 11), range=(0, 10))
        lbp_hist = lbp_hist / (lbp_hist.sum() + 1e-7)
        features.append(lbp_hist)

    if used_features['glcm']:
        glcm = graycomatrix(gray, distances=[1], angles=[0], symmetric=True, normed=True)
        contrast = graycoprops(glcm, prop='contrast').flatten()
        correlation = graycoprops(glcm, prop='correlation').flatten()
        energy = graycoprops(glcm, prop='energy').flatten()
        homogeneity = graycoprops(glcm, prop='homogeneity').flatten()
        features.extend([contrast, correlation, energy, homogeneity])

    return np.concatenate(features)

# %% [markdown]
# # Load Data

# %%
x, y = [], []
CATEGORIES = os.listdir(DATA_DIR)
CATEGORIES.remove('.DS_Store')
for idx, category in enumerate(CATEGORIES):
    folder = os.path.join(DATA_DIR, category)
    for file in os.listdir(folder):
        filepath = os.path.join(folder, file)
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            x.append(filepath)
            y.append(idx)
x = np.array(x)
y = np.array(y)

extracted_features = []
for img_path in x:
    features = extract_features(img_path)
    extracted_features.append(features)
extracted_features = np.array(extracted_features)

x_train, x_test, y_train, y_test = train_test_split(extracted_features, y, test_size=0.2, random_state=42, stratify=y)

# %% [markdown]
# # MLP Classifier

# %%
mlp_param_grid = {
    'hidden_layer_sizes': [(32, ), (64,), (128, ), (100,), (100, 50), (100, 100, 50)],
    'activation': ['relu', 'tanh', 'logistic'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive'],
    'max_iter': [200, 500, 1000]
}
mlp = MLPClassifier(random_state=42)
mlp_grid_search = GridSearchCV(mlp, mlp_param_grid, cv=5, n_jobs=-1, verbose=2)
mlp_grid_search.fit(x_train, y_train)
print("MLP Best parameters found:", mlp_grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 972 candidates, totalling 4860 fits
# MLP Best parameters found: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (32,), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}

# %% [markdown]
# # Gaussian Naive Bayes

# %%
gnb_param_grid = {
    'var_smoothing': np.logspace(-9, -6, 4)
}
gnb = GaussianNB()
gnb_grid_search = GridSearchCV(gnb, {'var_smoothing': gnb_param_grid['var_smoothing']}, cv=5, n_jobs=-1, verbose=2)
gnb_grid_search.fit(x_train, y_train)
print("GNB Best parameters found:", gnb_grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# GNB Best parameters found: {'var_smoothing': 1e-09}

# %% [markdown]
# # SVM Classifier

# %%
svm_param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
    'gamma': ['scale', 'auto']
}
svm = SVC(probability=True)
svm_grid_search = GridSearchCV(svm, svm_param_grid, cv=5, n_jobs=-1, verbose=2)
svm_grid_search.fit(x_train, y_train)
print("SVM Best parameters found:", svm_grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=500, solver=adam; total time=  25.5s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1000, solver=sgd; total time=  23.8s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=200, solver=sgd; total time=  14.0s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=  16.1s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=200, solver=adam; total time=  22.7s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=500, solver=sgd; total time=  53.0s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(100, 100, 50), learning_rate=constant, max_iter=500, solver=adam; total time=  36.7s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(100, 100, 50), learning_rate=constant, max_iter=1000, solver=sgd; total time=  14.1s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(100, 100, 50), learning_rate=invscaling, max_iter=200, solver=adam; total time=  29.4s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=(100, 100, 50), learning_rate=adaptive, max_iter
0s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(100, 100, 50), learning_rate=adaptive, max_iter=500, solver=adam; total time=  34.2s
# [CV] END activation=tanh, alpha=0.01, hidden_layer_sizes=(100, 100, 50), learning_rate=adaptive, max_iter=1000, solver=sgd; total time= 2.2min
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(64,), learning_rate=constant, max_iter=1000, solver=sgd; total time=  53.9s
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(64,), learning_rate=adaptive, max_iter=200, solver=sgd; total time=  11.0s
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(64,), learning_rate=adaptive, max_iter=500, solver=sgd; total time=  27.5s
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=200, solver=adam; total time=  12.8s
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=200, solver=sgd; total time=  12.3s
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=500, solver=adam; total time=  32.8s
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=200, solver=adam; total time=  13.8s
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=200, solver=sgd; total time=   1.9s
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=500, solver=adam; total time=  34.9s
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   2.0s
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=200, solver=sgd; total time=  13.4s
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=500, solver=sgd; total time=  32.6s
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1000, solver=adam; total time= 1.2min
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=500, solver=sgd; total time=  48.9s
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=200, solver=adam; total time=  19.9s
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100, 50), learning_rate=invscaling, max_iter=1000, solver=adam; total time= 1.2min
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1000, solver=adam; total time= 1.5min
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100, 100, 50), learning_rate=constant, max_iter=500, solver=adam; total time= 1.7min
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100, 100, 50), learning_rate=invscaling, max_iter=1000, solver=adam; total time= 2.1min
# [CV] END activation=logistic, alpha=0.0001, hidden_layer_sizes=(100, 100, 50), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=  14.0s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=200, solver=sgd; total time=   6.1s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=500, solver=sgd; total time=  14.6s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=500, solver=sgd; total time=  15.3s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(1,), learning_rate=constant, max_iter=1000, solver=sgd; total time=  27.8s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.5s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(1,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   0.4s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=200, solver=adam; total time=   6.9s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=200, solver=sgd; total time=   6.0s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=500, solver=sgd; total time=  11.8s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=  27.1s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(64,), learning_rate=constant, max_iter=500, solver=sgd; total time=  28.3s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(64,), learning_rate=invscaling, max_iter=200, solver=adam; total time=  11.3s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(64,), learning_rate=invscaling, max_iter=500, solver=sgd; total time=   1.5s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(64,), learning_rate=invscaling, max_iter=500, solver=sgd; total time=   1.6s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(64,), learning_rate=invscaling, max_iter=500, solver=sgd; total time=   1.6s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(64,), learning_rate=invscaling, max_iter=500, solver=sgd; total time=   1.5s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(64,), learning_rate=invscaling, max_iter=500, solver=sgd; total time=   2.0s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(64,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=  53.5s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(64,), learning_rate=adaptive, max_iter=1000, solver=adam; total time=  50.2s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=500, solver=sgd; total time=  37.5s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=200, solver=adam; total time=  16.8s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=200, solver=sgd; total time=   2.8s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=500, solver=adam; total time=  40.3s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1000, solver=sgd; total time=   2.5s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=200, solver=sgd; total time=  16.6s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=500, solver=adam; total time=  41.7s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=200, solver=adam; total time=  23.5s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=200, solver=sgd; total time=  23.1s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=500, solver=sgd; total time=  53.6s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1000, solver=sgd; total time= 1.3min
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=200, solver=sgd; total time=  18.6s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=500, solver=sgd; total time=  50.9s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 100, 50), learning_rate=constant, max_iter=200, solver=adam; total time=  35.7s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 100, 50), learning_rate=constant, max_iter=500, solver=sgd; total time=   3.8s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 100, 50), learning_rate=constant, max_iter=1000, solver=adam; total time= 1.8min
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 100, 50), learning_rate=adaptive, max_iter=200, solver=adam; total time=  30.7s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 100, 50), learning_rate=adaptive, max_iter=500, solver=sgd; total time=  11.3s
# [CV] END activation=logistic, alpha=0.001, hidden_layer_sizes=(100, 100, 50), learning_rate=adaptive, max_iter=1000, solver=adam; total time= 1.6min
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(1,), learning_rate=adaptive, max_iter=500, solver=sgd; total time=  11.7s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(64,), learning_rate=constant, max_iter=200, solver=sgd; total time=   8.9s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(64,), learning_rate=constant, max_iter=500, solver=adam; total time=  26.0s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(64,), learning_rate=constant, max_iter=1000, solver=sgd; total time=  52.1s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(64,), learning_rate=adaptive, max_iter=500, solver=adam; total time=  33.7s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(64,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time=  55.4s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100,), learning_rate=constant, max_iter=1000, solver=adam; total time=  34.4s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100,), learning_rate=invscaling, max_iter=1000, solver=adam; total time=  36.2s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=500, solver=adam; total time=  38.8s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100,), learning_rate=adaptive, max_iter=1000, solver=sgd; total time= 1.2min
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, max_iter=1000, solver=sgd; total time= 1.2min
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=500, solver=adam; total time=  47.8s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, max_iter=1000, solver=sgd; total time= 1.1min
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 100, 50), learning_rate=invscaling, max_iter=200, solver=sgd; total time=   3.9s
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 100, 50), learning_rate=invscaling, max_iter=500, solver=adam; total time= 1.3min
# [CV] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 100, 50), learning_rate=adaptive, max_iter=1000, solver=adam; total time=  42.0s
# [CV] END ................................var_smoothing=1e-07; total time=   0.0s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=  12.1s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=  14.1s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=  38.8s
# [CV] END .......................C=1, gamma=auto, kernel=poly; total time= 1.1min
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=  11.2s
# [CV] END ......................C=10, gamma=auto, kernel=poly; total time= 3.2min
# [CV] END ..................C=100, gamma=auto, kernel=sigmoid; total time=   8.7s
# [CV] END ..................C=100, gamma=auto, kernel=sigmoid; total time=   9.4s
# [CV] END ..................C=100, gamma=auto, kernel=sigmoid; total time=   9.9s
# [CV] END ..................C=100, gamma=auto, kernel=sigmoid; total time=  10.2s
# [CV] END ..................C=100, gamma=auto, kernel=sigmoid; total time=   9.7s
# SVM Best parameters found: {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}

# %% [markdown]
# # KNN Classifier

# %%
knn_param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}
knn = KNeighborsClassifier()
knn_grid_search = GridSearchCV(knn, knn_param_grid, cv=5, n_jobs=-1, verbose=2)
knn_grid_search.fit(x_train, y_train)
print("KNN Best parameters found:", knn_grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# KNN Best parameters found: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}

# %% [markdown]
# # Evaluate models

# %%
models = {
    'MLP': mlp_grid_search.best_estimator_,
    'KNN': knn_grid_search.best_estimator_,
    'SVM': svm_grid_search.best_estimator_,
    'GNB': gnb_grid_search.best_estimator_
}

for model_name, model in models.items():
    y_pred = model.predict(x_test)
    acc = accuracy_score(y_test, y_pred)
    print(f"{model_name} Accuracy: {acc}")
    print(f"{model_name} Classification Report:\n", classification_report(y_test, y_pred, target_names=CATEGORIES))
    print(f"{model_name} Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# MLP Accuracy: 0.98
# MLP Classification Report:
#                    precision    recall  f1-score   support
#
# Bacterial Canker       1.00      0.99      0.99       100
#      Anthracnose       0.99      0.97      0.98       100
#          Healthy       0.98      0.98      0.98       100
#   Powdery Mildew       0.97      0.99      0.98       100
#   Cutting Weevil       1.00      1.00      1.00       100
#         Die Back       0.98      1.00      0.99       100
#      Sooty Mould       0.96      0.95      0.95       100
#       Gall Midge       0.96      0.96      0.96       100
#
#         accuracy                           0.98       800
#        macro avg       0.98      0.98      0.98       800
#     weighted avg       0.98      0.98      0.98       800
#
# MLP Confusion Matrix:
#  [[ 99   0   0   0   0   0   1   0]
#  [  0  97   1   0   0   0   0   2]
#  [  0   0  98   0   0   1   1   0]
#  [  0   0   0  99   0   0   1   0]
#  [  0   0   0   0 100   0   0   0]
#  [  0   0   0   0   0 100   0   0]
#  [  0   0   1   2   0   0  95   2]
#  [  0   1   0   1   0   1   1  96]]
# KNN Accuracy: 0.86375
# KNN Classification Report:
#                    precision    recall  f1-score   support
#
# Bacterial Canker       0.94      0.88      0.91       100
#      Anthracnose       0.90      0.84      0.87       100
#          Healthy       0.93      0.86      0.90       100
#   Powdery Mildew       0.87      0.82      0.85       100
#   Cutting Weevil       0.92      0.98      0.95       100
#         Die Back       0.91      0.94      0.93       100
#      Sooty Mould       0.71      0.77      0.74       100
#       Gall Midge       0.75      0.82      0.78       100
#
#         accuracy                           0.86       800
#        macro avg       0.87      0.86      0.86       800
#     weighted avg       0.87      0.86      0.86       800
#
# KNN Confusion Matrix:
#  [[88  0  0  0  0  0 11  1]
#  [ 0 84  0  4  4  7  0  1]
#  [ 1  2 86  1  2  0  3  5]
#  [ 1  2  2 82  1  0 10  2]
#  [ 0  0  0  0 98  2  0  0]
#  [ 0  2  1  0  1 94  0  2]
#  [ 3  0  0  4  0  0 77 16]
#  [ 1  3  3  3  1  0  7 82]]
# SVM Accuracy: 0.97
# SVM Classification Report:
#                    precision    recall  f1-score   support
#
# Bacterial Canker       0.99      0.98      0.98       100
#      Anthracnose       0.99      0.93      0.96       100
#          Healthy       0.98      1.00      0.99       100
#   Powdery Mildew       0.94      0.96      0.95       100
#   Cutting Weevil       0.97      1.00      0.99       100
#         Die Back       0.98      0.99      0.99       100
#      Sooty Mould       0.95      0.93      0.94       100
#       Gall Midge       0.96      0.97      0.97       100
#
#         accuracy                           0.97       800
#        macro avg       0.97      0.97      0.97       800
#     weighted avg       0.97      0.97      0.97       800
#
# SVM Confusion Matrix:
#  [[ 98   0   0   0   0   0   2   0]
#  [  0  93   2   0   2   1   0   2]
#  [  0   0 100   0   0   0   0   0]
#  [  0   0   0  96   0   1   3   0]
#  [  0   0   0   0 100   0   0   0]
#  [  0   0   0   0   1  99   0   0]
#  [  1   0   0   4   0   0  93   2]
#  [  0   1   0   2   0   0   0  97]]
# GNB Accuracy: 0.88625
# GNB Classification Report:
#                    precision    recall  f1-score   support
#
# Bacterial Canker       0.96      0.90      0.93       100
#      Anthracnose       0.91      0.96      0.93       100
#          Healthy       0.91      0.88      0.89       100
#   Powdery Mildew       0.86      0.90      0.88       100
#   Cutting Weevil       0.86      0.96      0.91       100
#         Die Back       0.93      0.79      0.85       100
#      Sooty Mould       0.76      0.80      0.78       100
#       Gall Midge       0.94      0.90      0.92       100
#
#         accuracy                           0.89       800
#        macro avg       0.89      0.89      0.89       800
#     weighted avg       0.89      0.89      0.89       800
#
# GNB Confusion Matrix:
#  [[90  0  0  0  0  0  9  1]
#  [ 0 96  0  1  0  3  0  0]
#  [ 0  6 88  3  0  1  2  0]
#  [ 0  1  0 90  0  0  8  1]
#  [ 0  3  0  0 96  1  0  0]
#  [ 0  0  0  4 16 79  1  0]
#  [ 2  0  9  5  0  0 80  4]
#  [ 2  0  0  2  0  1  5 90]]
